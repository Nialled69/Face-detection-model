# %% [markdown]
# #### Pre downloaded the following dependencies to avoid dependency version closed loop

# %%
pip install mediapipe face_recognition opencv-python numpy pandas insightface scikit-learn tensorflow deepface

# %% [markdown]
# ##### Installing the dependencies mentioned in requirements.txt

# %%
pip install -r requirements.txt

# %% [markdown]
# ##### Reinstalling additional libraries of older versions to avoid dependency loop

# %%
pip install "joblib~=1.1.0" "packaging<24" "FuzzyTM>=0.4.0"

# %% [markdown]
# ##### Libraries required for building the REST API(s)

# %%
pip install fastapi uvicorn python-multipart requests
# Out:
# ...
#
# ...

# %% [markdown]
# ##### Checking the python environment to utlise the same libraries in bulding the microservices

# %%
import sys
print(sys.executable)
# Out:
# D:\Anaconda\python.exe
